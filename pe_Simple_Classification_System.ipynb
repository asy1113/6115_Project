# %% [markdown]
# # NLP System

# %%
# Main NLP Class

from pipeUtils import Document
from pipeUtils import Annotation
import re

class PadClassificationSystem:
    def __init__(self):
        #initiate necessary components        
        self.target_rules=self.getTargetRegexes()        
        self.negation_rules = self.getNegRegexes()
                
    def process(self, document):
        document_id = document.document_id
        ann_index=0
        for reg in self.target_rules:
            for match in reg.finditer(document.text):
                ann_id = 'NLP_'+ str(document_id) + '_' + str(ann_index)
                ann_index=ann_index+1
                new_annotation = Annotation(start_index=int(match.start()), 
                                    end_index=int(match.end()), 
                                    type='pe_ann',
                                    ann_id = ann_id
                                    )
                new_annotation.spanned_text = document.text[new_annotation.start_index:new_annotation.end_index]

                # Check negation right before the found target up to 30 charachers before, 
                # making sure that the pre-text does not cross the text boundary and is valid

                if new_annotation.start_index - 30 > 0:
                    pre_text_start = new_annotation.start_index - 30
                else:
                    pre_text_start = 0

                # ending index of the pre_text is the beginning of the found target    
                pre_text_end = new_annotation.start_index    

                # substring the document text to identify the pre_text string
                pre_text = doc.text[pre_text_start: pre_text_end]

                # We do not need to know the exact location of the negation keyword, so re.search is acceptable
                for neg_regex in self.negation_rules:
                    if re.search(neg_regex, pre_text):
                        new_annotation.attributes["Negation"] ="Negated"

                document.annotations.append(new_annotation)
        
        return document 
    
    def getTargetRegexes(self):
        target_regexes = []
        regexes = [            
            r'\bpe\b',
            r'\b(pulmonary|septic)?(\s{0,10})?(artery)?(\s{0,10})?(embolism|emboli|embolus)\b'
        ]
        for reg in regexes:
            target_regexes.append(re.compile(reg, re.IGNORECASE))
        return target_regexes

    def getNegRegexes(self):
        target_regexes = []
        regexes = [            
            r'evidence of'  ,
            r'does not have',
            r'denies',
            r'neg for',
            r'negative for',
            r'no central',
            r'no filling defect',
            r'\bno\s{1,10}(?=pe)',
            r'\bno\s{1,10}(?=pulmonary embolism)',
            r'bno\s{1,10}(?=septic embolism)',
            r'low likelihood',
            r'less likely',
            r'low suspicion for'
            
        ]
        for reg in regexes:
            target_regexes.append(re.compile(reg, re.IGNORECASE))
        return target_regexes

# %% [markdown]
# ## Classification

# %%
# pe notes
import os
unid = 'u0496358'
path = "/home/"+str(unid)+"/BRAT/"+str(unid)+"/Project_pe_test" 
files = os.listdir(path)
len(files)
# Out:
# 44

# %%
nlp_system = PadClassificationSystem()

import chardet
docs=dict()  

for i in files[:]:
    if ".txt" in i:                   
         
        with open(os.path.join(path,i), 'rb') as f:
            doc_txt = chardet.detect(f.read())        
        
        with open(os.path.join(path,i),encoding=doc_txt["encoding"]) as f:
            doc_text = f.read()           
            
            doc=Document(text=doc_text)            
            out_doc=nlp_system.process(doc)
            
            docs[i] = out_doc

# %%
doc_class=dict()
for k, v in docs.items():
    doc_class[k] = "pe_doc"
    for anns in docs[k].annotations:
        #print(anns.attributes)
        if anns.attributes != {}:
            doc_class[k] = "no_pe"
            break
            
for k in doc_class:
    print(k, '---', doc_class[k])
# Out:
# 90688_292.txt --- no_pe
# 65675_64.txt --- no_pe
# 48640_63.txt --- no_pe
# 86087_123.txt --- pe_doc
# 83838_106.txt --- pe_doc
# 72554_306.txt --- no_pe
# 15899_182.txt --- pe_doc
# 13867_266.txt --- pe_doc
# 61180_73.txt --- pe_doc
# 32113_141.txt --- no_pe
# 59381_293.txt --- pe_doc
# 58515_159.txt --- pe_doc
# 6878_279.txt --- no_pe
# 820_14.txt --- pe_doc
# 32113_109.txt --- pe_doc
# 49079_68.txt --- pe_doc
# 10568_20.txt --- no_pe
# 25764_268.txt --- no_pe
# 1498_225.txt --- no_pe
# 82326_55.txt --- pe_doc

# %% [markdown]
# ## Document Level Validation

# %%
path = path
posLab = "pe_doc"   #positive_DOC
negLab = "no_pe"    #negative_DOC
from pynlp_valid import Validnote
validnote = Validnote()
std_doc = validnote.readstd_ann(path, posLab, negLab)
precision, recall, f1 = validnote.validation(doc_class, std_doc, posLab, negLab)
print("*"*20)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1: ", f1)
# Out:
# fn --- 90688_292.txt
# fp --- 83838_106.txt
# fp --- 61180_73.txt
# 	Reference 	 Total
# System 	 9 	 2 	 11
# System 	 1 	 8 	 9
# Total 	 10 	 10
# ********************
# Precision:  0.8181818181818182
# Recall:  0.9
# F1:  0.8571428571428572

# %%
# %%time
#  test case
nlp_system = PadClassificationSystem()
doc_text = '''
Patient has peripheral artery disease. ---------- \nPatient also has PVD or peripheral vascular\ndisease or pvd . 
\n The patient does not have any peripheral artery disease 
but has peripheral arterial disease . The patient denies having peripheral vascular disease . \n 
The patient has a femoral and illiac occlusion which is suggestive of peripheral arterial disease.
'''
doc=Document(text=doc_text, document_id='Doc1')
 
out_doc=nlp_system.process(doc)
print(out_doc.toString())
# Out:
# Doc1
# -------
#
# Patient has peripheral artery disease. ----------
# Patient also has PVD or peripheral vascular
# disease or pvd .
#
#  The patient does not have any peripheral artery disease
# but has peripheral arterial disease . The patient denies having peripheral vascular disease .
#
# The patient has a femoral and illiac occlusion which is suggestive of peripheral arterial disease.
#
# -------
#
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 418 µs

# %% [markdown]
# ## Mention Level Validation

# %%
from pipeUtils import Annotation
from pipeUtils import Document
 
import os
import glob

# %%
# Read all test documents
unid='u0496358'
project_1 = "Project_pe_train"
project_2 = "Project_pe_test"
path_1 = "/home/"+str(unid)+"/BRAT/"+str(unid)+"/"+project_1
path_2 = "/home/"+str(unid)+"/BRAT/"+str(unid)+"/"+project_2

# %%
test_docs=dict()
test_doc_paths = glob.glob(str(path_2+'/*.txt')) 
for d in test_doc_paths:
    doc = Document()
    #print(d)
    doc.load_document_from_file(d)
    #print(str(d[:-3])+'ann')
    doc.load_annotations_from_brat(str(d[:-3])+'ann')
    #print(os.path.basename(d))
    test_docs[os.path.basename(d)]=doc


#test_docs

# %%
# Processing the all notes
nlp_system = PadClassificationSystem()

for doc_id in  test_docs.keys():

    test_docs[doc_id] = nlp_system.process(test_docs.get(doc_id))

# %%
print(test_docs.get("10568_20.txt").annotations[1].attributes)
test_docs.get("10568_20.txt").annotations[1].attributes=={'Negation': 'Negated'}
# Out:
# {'Negation': 'Negated'}
# True

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).compare_types_by_span('PE','pe_ann', False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 121 FP = 5 FN = 0
# Precision= 0.96
# Recall= 1.0
# NLP_90688_292.txt_0 pe_ann 154 156 PE  || T3 PE 154 156 PE
# NLP_90688_292.txt_1 pe_ann 459 461 PE  || T4 PE 459 461 PE
# NLP_90688_292.txt_2 pe_ann 653 655 PE  || T7 PE 653 655 PE
# NLP_90688_292.txt_3 pe_ann 688 690 PE  || T5 PE 688 690 PE [Negation:Negated]
# NLP_90688_292.txt_4 pe_ann 3154 3156 PE  || T6 PE 3154 3156 PE
# NLP_90688_292.txt_5 pe_ann 6332 6334 PE  || T8 PE 6332 6334 PE
# NLP_90688_292.txt_6 pe_ann 929 947 pulmonary embolism  || T9 PE 929 947 pulmonary embolism [Negation:Affirmed]
# NLP_90688_292.txt_7 pe_ann 2051 2068 pulmonary embolus  || T13 PE 2051 2068 pulmonary embolus
# NLP_90688_292.txt_8 pe_ann 3777 3795 pulmonary embolism  || T10 PE 3777 3795 pulmonary embolism [Negation:Affirmed]
# NLP_90688_292.txt_9 pe_ann 3968 3985 pulmonary embolus  || T14 PE 3968 3985 pulmonary embolus [Negation:Negated]
# NLP_90688_292.txt_10 pe_ann 4648 4666 pulmonary embolism  || T11 PE 4648 4666 pulmonary embolism
# NLP_90688_292.txt_11 pe_ann 5671 5689 pulmonary embolism  || T12 PE 5671 5689 pulmonary embolism [Negation:Affirmed]
# NLP_65675_64.txt_1 pe_ann 2062 2064 PE  || T2 PE 2062 2064 PE
# NLP_65675_64.txt_2 pe_ann 2025 2043 pulmonary embolism  || T1 PE 2025 2043 pulmonary embolism [Negation:Negated]
# NLP_65675_64.txt_3 pe_ann 2492 2510 pulmonary embolism  || T3 PE 2492 2510 pulmonary embolism [Temporality:Historical][Negation:Negated]
# NLP_65675_64.txt_4 pe_ann 10094 10112 pulmonary embolism  || T4 PE 10094 10112 pulmonary embolism [Negation:Negated]
# NLP_48640_63.txt_0 pe_ann 12822 12824 PE  || T2 PE 12822 12824 PE [Negation:Negated]
# NLP_48640_63.txt_1 pe_ann 8302 8320 pulmonary embolism  || T3 PE 8302 8320 pulmonary embolism [Negation:Negated]
# NLP_86087_123.txt_0 pe_ann 7114 7135 pulmonary
#    embolism  || T1 PE 7114 7135 pulmonary    embolism [Negation:Negated]
# NLP_86087_123.txt_1 pe_ann 7744 7762 Pulmonary embolism  || T2 PE 7744 7762 Pulmonary embolism
# NLP_86087_123.txt_2 pe_ann 7915 7933 pulmonary embolism  || T3 PE 7915 7933 pulmonary embolism [Negation:Negated]
# NLP_83838_106.txt_0 pe_ann 1018 1020 PE  || T5 PE 1018 1020 PE
# NLP_83838_106.txt_1 pe_ann 6215 6217 PE  || T6 PE 6215 6217 PE
# NLP_83838_106.txt_2 pe_ann 6244 6246 PE  || T7 PE 6244 6246 PE [Negation:Negated]
# NLP_83838_106.txt_3 pe_ann 6801 6803 PE  || T8 PE 6801 6803 PE
# NLP_83838_106.txt_4 pe_ann 7017 7019 PE  || T9 PE 7017 7019 PE
# NLP_83838_106.txt_5 pe_ann 7286 7288 PE  || T10 PE 7286 7288 PE [Negation:Negated]
# NLP_83838_106.txt_6 pe_ann 5548 5566 pulmonary embolism  || T11 PE 5548 5566 pulmonary embolism [Negation:Negated]
# NLP_72554_306.txt_4 pe_ann 1072 1090 pulmonary embolism  || T1 PE 1072 1090 pulmonary embolism
# NLP_72554_306.txt_5 pe_ann 4136 4154 pulmonary embolism  || T3 PE 4136 4154 pulmonary embolism [Negation:Negated]
# NLP_15899_182.txt_0 pe_ann 145 147 PE  || T3 PE 145 147 PE
# NLP_15899_182.txt_1 pe_ann 395 397 PE  || T4 PE 395 397 PE
# NLP_15899_182.txt_2 pe_ann 2948 2950 PE  || T5 PE 2948 2950 PE
# NLP_15899_182.txt_3 pe_ann 583 599 pulmonary emboli  || T8 PE 583 599 pulmonary emboli [Negation:Affirmed]
# NLP_15899_182.txt_4 pe_ann 846 859 septic emboli  || T9 PE 846 859 septic emboli [Negation:Affirmed]
# NLP_15899_182.txt_5 pe_ann 1481 1497 pulmonary emboli  || T10 PE 1481 1497 pulmonary emboli [Negation:Affirmed]
# NLP_15899_182.txt_6 pe_ann 2629 2645 pulmonary emboli  || T7 PE 2629 2645 pulmonary emboli [Negation:Affirmed]
# NLP_15899_182.txt_7 pe_ann 2685 2701 pulmonary emboli  || T6 PE 2685 2701 pulmonary emboli [Negation:Affirmed]
# NLP_15899_182.txt_8 pe_ann 3360 3375 septic
#  embolus  || T11 PE 3360 3375 septic  embolus
# NLP_13867_266.txt_0 pe_ann 157 159 PE  || T5 PE 157 159 PE
# NLP_13867_266.txt_1 pe_ann 496 498 PE  || T6 PE 496 498 PE
# NLP_13867_266.txt_2 pe_ann 801 803 PE  || T7 PE 801 803 PE
# NLP_13867_266.txt_3 pe_ann 2763 2765 PE  || T8 PE 2763 2765 PE
# NLP_13867_266.txt_4 pe_ann 1125 1143 pulmonary embolism  || T2 PE 1125 1143 pulmonary embolism [Negation:Negated][Temporality:Historical]
# NLP_13867_266.txt_5 pe_ann 1474 1493 pulmonary
#  embolism  || T3 PE 1474 1493 pulmonary  embolism
# NLP_13867_266.txt_6 pe_ann 2323 2341 pulmonary embolism  || T4 PE 2323 2341 pulmonary embolism [Negation:Affirmed]
# NLP_61180_73.txt_0 pe_ann 8712 8714 PE  || T5 PE 8712 8714 PE
# NLP_61180_73.txt_1 pe_ann 8779 8781 PE  || T4 PE 8779 8781 PE [Negation:Negated]
# NLP_61180_73.txt_2 pe_ann 2029 2047 Pulmonary embolism  || T6 PE 2029 2047 Pulmonary embolism
# NLP_61180_73.txt_3 pe_ann 8488 8506 pulmonary embolism  || T7 PE 8488 8506 pulmonary embolism
# NLP_32113_141.txt_0 pe_ann 547 549 PE  || T3 PE 547 549 PE [Negation:Negated]
# NLP_32113_141.txt_1 pe_ann 9409 9411 PE  || T4 PE 9409 9411 PE
# NLP_32113_141.txt_2 pe_ann 11139 11141 PE  || T5 PE 11139 11141 PE [Negation:Negated]
# NLP_32113_141.txt_3 pe_ann 9543 9552  embolism  || T1 PE 9544 9552 embolism
# NLP_32113_141.txt_4 pe_ann 10284 10302 pulmonary embolism  || T2 PE 10284 10302 pulmonary embolism [Negation:Negated]
# NLP_59381_293.txt_0 pe_ann 167 169 PE  || T1 PE 167 169 PE
# NLP_59381_293.txt_1 pe_ann 603 605 PE  || T2 PE 603 605 PE
# NLP_59381_293.txt_2 pe_ann 973 975 PE  || T3 PE 973 975 PE [Negation:Affirmed]
# NLP_59381_293.txt_3 pe_ann 3143 3145 PE  || T4 PE 3143 3145 PE
# NLP_59381_293.txt_4 pe_ann 5862 5864 PE  || T5 PE 5862 5864 PE
# NLP_59381_293.txt_5 pe_ann 5056 5072 pulmonary emboli  || T6 PE 5056 5072 pulmonary emboli [Negation:Affirmed]
# NLP_58515_159.txt_0 pe_ann 5182 5184 PE  || T2 PE 5182 5184 PE
# NLP_58515_159.txt_1 pe_ann 7940 7942 PE  || T5 PE 7940 7942 PE
# NLP_58515_159.txt_2 pe_ann 8017 8019 PE  || T6 PE 8017 8019 PE
# NLP_58515_159.txt_3 pe_ann 8239 8241 PE  || T4 PE 8239 8241 PE
# NLP_58515_159.txt_4 pe_ann 10783 10785 PE  || T7 PE 10783 10785 PE
# NLP_58515_159.txt_5 pe_ann 5162 5180 PULMONARY EMBOLISM  || T1 PE 5162 5180 PULMONARY EMBOLISM
# NLP_58515_159.txt_6 pe_ann 8263 8281 Pulmonary embolism  || T3 PE 8263 8281 Pulmonary embolism
# NLP_6878_279.txt_0 pe_ann 163 165 PE  || T8 PE 163 165 PE
# NLP_6878_279.txt_1 pe_ann 382 384 PE  || T7 PE 382 384 PE
# NLP_6878_279.txt_2 pe_ann 551 553 PE  || T6 PE 551 553 PE [Negation:Negated]
# NLP_6878_279.txt_3 pe_ann 831 833 PE  || T5 PE 831 833 PE [Negation:Negated]
# NLP_6878_279.txt_4 pe_ann 3139 3141 PE  || T4 PE 3139 3141 PE
# NLP_6878_279.txt_5 pe_ann 1215 1233 pulmonary embolism  || T9 PE 1215 1233 pulmonary embolism
# NLP_6878_279.txt_6 pe_ann 2031 2049 pulmonary embolism  || T10 PE 2031 2049 pulmonary embolism [Negation:Negated]
# NLP_6878_279.txt_7 pe_ann 3502 3520 pulmonary embolism  || T3 PE 3502 3520 pulmonary embolism [Negation:Negated]
# NLP_820_14.txt_0 pe_ann 3003 3005 PE  || T7 PE 3003 3005 PE [Temporality:Historical]
# NLP_820_14.txt_1 pe_ann 8906 8908 PE  || T6 PE 8906 8908 PE
# NLP_820_14.txt_2 pe_ann 9466 9468 PE  || T4 PE 9466 9468 PE
# NLP_820_14.txt_3 pe_ann 9487 9489 PE  || T5 PE 9487 9489 PE
# NLP_820_14.txt_4 pe_ann 9754 9756 PE  || T3 PE 9754 9756 PE
# NLP_820_14.txt_5 pe_ann 1268 1286 pulmonary embolism  || T9 PE 1268 1286 pulmonary embolism [Temporality:Historical]
# NLP_820_14.txt_6 pe_ann 3706 3724 pulmonary embolism  || T10 PE 3706 3724 pulmonary embolism
# NLP_820_14.txt_7 pe_ann 4721 4739 Pulmonary embolism  || T11 PE 4721 4739 Pulmonary embolism
# NLP_820_14.txt_8 pe_ann 7657 7675 pulmonary
# embolism  || T12 PE 7657 7675 pulmonary embolism
# NLP_820_14.txt_9 pe_ann 13540 13556 Pulmonary Emboli  || T8 PE 13540 13556 Pulmonary Emboli [Negation:Affirmed]
# NLP_32113_109.txt_0 pe_ann 472 474 PE  || T2 PE 472 474 PE
# NLP_32113_109.txt_1 pe_ann 101 119 pulmonary embolism  || T4 PE 101 119 pulmonary embolism
# NLP_32113_109.txt_2 pe_ann 5978 5995 pulmonary embolus  || T7 PE 5978 5995 pulmonary embolus [Negation:Affirmed]
# NLP_32113_109.txt_3 pe_ann 6588 6606 pulmonary embolism  || T3 PE 6588 6606 pulmonary embolism
# NLP_32113_109.txt_4 pe_ann 7894 7912 Pulmonary embolism  || T5 PE 7894 7912 Pulmonary embolism
# NLP_32113_109.txt_5 pe_ann 7936 7953 pulmonary embolus  || T6 PE 7936 7953 pulmonary embolus [Negation:Affirmed]
# NLP_49079_68.txt_0 pe_ann 8999 9001 PE  || T2 PE 8999 9001 PE
# NLP_49079_68.txt_1 pe_ann 1497 1514 pulmonary
# embolus  || T5 PE 1497 1514 pulmonary embolus
# NLP_49079_68.txt_2 pe_ann 5094 5111 pulmonary embolus  || T6 PE 5094 5111 pulmonary embolus
# NLP_49079_68.txt_3 pe_ann 9404 9421 pulmonary embolus  || T7 PE 9404 9421 pulmonary embolus [Negation:Affirmed]
# NLP_49079_68.txt_4 pe_ann 9677 9694 pulmonary embolus  || T8 PE 9677 9694 pulmonary embolus [Negation:Affirmed]
# NLP_49079_68.txt_5 pe_ann 14690 14708 pulmonary
# embolism  || T4 PE 14690 14708 pulmonary embolism
# NLP_49079_68.txt_6 pe_ann 16322 16340 Pulmonary Embolism  || T3 PE 16322 16340 Pulmonary Embolism [Negation:Affirmed]
# NLP_10568_20.txt_0 pe_ann 1263 1265 PE  || T1 PE 1263 1265 PE
# NLP_10568_20.txt_1 pe_ann 6335 6353 pulmonary embolism  || T2 PE 6335 6353 pulmonary embolism [Negation:Negated]
# NLP_10568_20.txt_2 pe_ann 6987 7005 pulmonary embolism  || T3 PE 6987 7005 pulmonary embolism [Negation:Negated]
# NLP_25764_268.txt_0 pe_ann 150 152 PE  || T1 PE 150 152 PE
# NLP_25764_268.txt_1 pe_ann 354 356 PE  || T6 PE 354 356 PE
# NLP_25764_268.txt_2 pe_ann 523 525 PE  || T7 PE 523 525 PE [Negation:Negated]
# NLP_25764_268.txt_3 pe_ann 2661 2663 PE  || T5 PE 2661 2663 PE
# NLP_25764_268.txt_4 pe_ann 781 799 pulmonary embolism  || T2 PE 781 799 pulmonary embolism
# NLP_25764_268.txt_5 pe_ann 1372 1390 pulmonary embolism  || T3 PE 1372 1390 pulmonary embolism [Negation:Negated]
# NLP_25764_268.txt_6 pe_ann 2368 2386 pulmonary embolism  || T4 PE 2368 2386 pulmonary embolism [Negation:Negated]
# NLP_1498_225.txt_0 pe_ann 152 154 PE  || T1 PE 152 154 PE
# NLP_1498_225.txt_1 pe_ann 400 402 PE  || T2 PE 400 402 PE
# NLP_1498_225.txt_2 pe_ann 570 572 PE  || T3 PE 570 572 PE [Negation:Negated]
# NLP_1498_225.txt_3 pe_ann 833 851 pulmonary embolism  || T6 PE 833 851 pulmonary embolism
# NLP_1498_225.txt_4 pe_ann 1347 1365 pulmonary embolism  || T5 PE 1347 1365 pulmonary embolism [Negation:Negated]
# NLP_1498_225.txt_5 pe_ann 2040 2058 pulmonary embolism  || T4 PE 2040 2058 pulmonary embolism [Negation:Negated]
# NLP_82326_55.txt_0 pe_ann 6243 6261 pulmonary embolism  || T6 PE 6243 6261 pulmonary embolism
# NLP_82326_55.txt_1 pe_ann 6345 6358 septic emboli  || T1 PE 6345 6358 septic emboli [Negation:Affirmed]
# NLP_82326_55.txt_2 pe_ann 12529 12542 septic emboli  || T2 PE 12529 12542 septic emboli [Negation:Affirmed]
# NLP_82326_55.txt_3 pe_ann 13172 13185 Septic emboli  || T3 PE 13172 13185 Septic emboli
# NLP_82326_55.txt_4 pe_ann 13202 13215 septic emboli  || T4 PE 13202 13215 septic emboli [Negation:Affirmed]
# NLP_82326_55.txt_5 pe_ann 15955 15973 pulmonary embolism  || T5 PE 15955 15973 pulmonary embolism
# NLP_65675_64.txt_0 pe_ann 1343 1345 PE
# NLP_72554_306.txt_0 pe_ann 139 141 PE
# NLP_72554_306.txt_1 pe_ann 413 415 PE
# NLP_72554_306.txt_2 pe_ann 617 619 pe
# NLP_72554_306.txt_3 pe_ann 3334 3336 PE

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('PE', 'Negation', 'Negated'),('pe_ann', 'Negation', 'Negated')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).compare_types_by_span_and_attributes('PE','pe_ann', False)
    #compare_types_by_span_and_attributes('PE','pe_ann', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

#for a in tp_list_total:
#    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 89 FP = 37 FN = 32
# Precision= 0.706
# Recall= 0.736
# NLP_90688_292.txt_3 pe_ann 688 690 PE
# NLP_90688_292.txt_9 pe_ann 3968 3985 pulmonary embolus
# NLP_65675_64.txt_0 pe_ann 1343 1345 PE
# NLP_65675_64.txt_2 pe_ann 2025 2043 pulmonary embolism
# NLP_65675_64.txt_3 pe_ann 2492 2510 pulmonary embolism
# NLP_65675_64.txt_4 pe_ann 10094 10112 pulmonary embolism
# NLP_48640_63.txt_0 pe_ann 12822 12824 PE
# NLP_48640_63.txt_1 pe_ann 8302 8320 pulmonary embolism
# NLP_86087_123.txt_0 pe_ann 7114 7135 pulmonary
#    embolism
# NLP_86087_123.txt_2 pe_ann 7915 7933 pulmonary embolism
# NLP_83838_106.txt_2 pe_ann 6244 6246 PE
# NLP_83838_106.txt_5 pe_ann 7286 7288 PE
# NLP_83838_106.txt_6 pe_ann 5548 5566 pulmonary embolism
# NLP_72554_306.txt_0 pe_ann 139 141 PE
# NLP_72554_306.txt_1 pe_ann 413 415 PE
# NLP_72554_306.txt_2 pe_ann 617 619 pe
# NLP_72554_306.txt_3 pe_ann 3334 3336 PE
# NLP_72554_306.txt_5 pe_ann 4136 4154 pulmonary embolism
# NLP_13867_266.txt_4 pe_ann 1125 1143 pulmonary embolism
# NLP_61180_73.txt_1 pe_ann 8779 8781 PE
# NLP_32113_141.txt_0 pe_ann 547 549 PE
# NLP_32113_141.txt_2 pe_ann 11139 11141 PE
# NLP_32113_141.txt_4 pe_ann 10284 10302 pulmonary embolism
# NLP_6878_279.txt_2 pe_ann 551 553 PE
# NLP_6878_279.txt_3 pe_ann 831 833 PE
# NLP_6878_279.txt_6 pe_ann 2031 2049 pulmonary embolism
# NLP_6878_279.txt_7 pe_ann 3502 3520 pulmonary embolism
# NLP_820_14.txt_0 pe_ann 3003 3005 PE
# NLP_820_14.txt_5 pe_ann 1268 1286 pulmonary embolism
# NLP_10568_20.txt_1 pe_ann 6335 6353 pulmonary embolism
# NLP_10568_20.txt_2 pe_ann 6987 7005 pulmonary embolism
# NLP_25764_268.txt_2 pe_ann 523 525 PE
# NLP_25764_268.txt_5 pe_ann 1372 1390 pulmonary embolism
# NLP_25764_268.txt_6 pe_ann 2368 2386 pulmonary embolism
# NLP_1498_225.txt_2 pe_ann 570 572 PE
# NLP_1498_225.txt_4 pe_ann 1347 1365 pulmonary embolism
# NLP_1498_225.txt_5 pe_ann 2040 2058 pulmonary embolism
# T5 PE 688 690 PE [Negation:Negated]
# T14 PE 3968 3985 pulmonary embolus [Negation:Negated]
# T1 PE 2025 2043 pulmonary embolism [Negation:Negated]
# T3 PE 2492 2510 pulmonary embolism [Temporality:Historical][Negation:Negated]
# T4 PE 10094 10112 pulmonary embolism [Negation:Negated]
# T2 PE 12822 12824 PE [Negation:Negated]
# T3 PE 8302 8320 pulmonary embolism [Negation:Negated]
# T1 PE 7114 7135 pulmonary    embolism [Negation:Negated]
# T3 PE 7915 7933 pulmonary embolism [Negation:Negated]
# T7 PE 6244 6246 PE [Negation:Negated]
# T10 PE 7286 7288 PE [Negation:Negated]
# T11 PE 5548 5566 pulmonary embolism [Negation:Negated]
# T3 PE 4136 4154 pulmonary embolism [Negation:Negated]
# T2 PE 1125 1143 pulmonary embolism [Negation:Negated][Temporality:Historical]
# T4 PE 8779 8781 PE [Negation:Negated]
# T2 PE 10284 10302 pulmonary embolism [Negation:Negated]
# T3 PE 547 549 PE [Negation:Negated]
# T5 PE 11139 11141 PE [Negation:Negated]
# T3 PE 3502 3520 pulmonary embolism [Negation:Negated]
# T5 PE 831 833 PE [Negation:Negated]
# T6 PE 551 553 PE [Negation:Negated]
# T10 PE 2031 2049 pulmonary embolism [Negation:Negated]
# T7 PE 3003 3005 PE [Temporality:Historical]
# T9 PE 1268 1286 pulmonary embolism [Temporality:Historical]
# T2 PE 6335 6353 pulmonary embolism [Negation:Negated]
# T3 PE 6987 7005 pulmonary embolism [Negation:Negated]
# T3 PE 1372 1390 pulmonary embolism [Negation:Negated]
# T4 PE 2368 2386 pulmonary embolism [Negation:Negated]
# T7 PE 523 525 PE [Negation:Negated]
# T3 PE 570 572 PE [Negation:Negated]
# T4 PE 2040 2058 pulmonary embolism [Negation:Negated]
# T5 PE 1347 1365 pulmonary embolism [Negation:Negated]

# %% [markdown]
# ## System deployment

# %%
# imports
import pymysql
import pandas as pd
import getpass

# %%
conn = pymysql.connect(host="mysql.chpc.utah.edu",
                       port=3306,user="mimicclass",
                       getpass.getpass("Enter MySQL passwd for jovyan"),                       
                       db='mimic3')
cursor = conn.cursor()

# %%
# identify patients with PAD for reference standard
# pad_data 
docs_text = pd.read_sql("SELECT subject_id, text from NOTEEVENTS where text like '%d-dimer% CT %pulmonary emboli%'",conn)

# %%
try:
    conn.close()
except:
    print("Connection is already closed!")

# %%
print(docs_text.columns)
print("Number of records = ", len(docs_text))

docs_text.head(1)
# Out:
# Index(['subject_id', 'text'], dtype='object')
# Number of records =  335
#    subject_id                                               text
# 0       83596  Admission Date:  [**3012-10-23**]             ...

# %%
final_nlp_system = PadClassificationSystem()

# %%
output = []
counter = 0
for index , row in docs_text.iterrows():    
    doc = Document(document_id=str(row.subject_id) + '_' + str(index), text=row.text)
    final_nlp_system.process(doc)
    if(len(doc.annotations) > 0):
        i = 1
        for a in doc.annotations:
            if( a.type == 'pe_ann'):
                neg_flag = 0
                # Switch the flag to 1 when the mention is negated
                # if('Negated' in a.attributes): # definite_negated_existence Negated
                if a.attributes == {'Negation': 'Negated'}:
                    neg_flag=1
                ### Each row in the dictionary
                record_id  = str(row.subject_id) + '_' + str(index)+'_'+str(i)
                subject_id =  row.subject_id
                note_id = str(row.subject_id) + '_' + str(index)
                annotation_type = a.type
                snippet = doc.text[int(a.start_index): int(a.end_index)]
                out_list = [record_id, subject_id, note_id, annotation_type, \
                            a.start_index, a.end_index, \
                            snippet, neg_flag]
                output.append(out_list)
                i=i+1
                counter=counter+1
                # Print . after 10 identified records
                if counter%10 == 0:
                    print('.', end='')
        else:
            continue
        break
# Out:
# .............................................................................................................................................................................................

# %% [markdown]
# # Output to CSV file

# %%
columns=['record_id','subject_id', 'note_id', 'annotation_type', 'span_start', 'span_end', 'PAD_snippet', 'neg_flag']
result_data_frame = (pd.DataFrame(output, columns=columns))

result_data_frame.describe()
# Out:
#          subject_id    span_start      span_end     neg_flag
# count   1899.000000   1899.000000   1899.000000  1899.000000
# mean   44528.308583   4379.319115   4389.332807     0.141654
# std    29256.248082   4884.309205   4885.378241     0.348786
# min      105.000000     18.000000     29.000000     0.000000
# 25%    15899.000000    746.500000    753.000000     0.000000
# 50%    46399.000000   2512.000000   2522.000000     0.000000
# 75%    69251.000000   6886.000000   6888.000000     0.000000
# max    98982.000000  31395.000000  31408.000000     1.000000

# %%
result_data_frame
# Out:
#         record_id  subject_id    note_id annotation_type  span_start  \
# 0       83596_0_1       83596    83596_0          pe_ann        1982
# 1       83596_0_2       83596    83596_0          pe_ann       16910
# 2       83596_0_3       83596    83596_0          pe_ann       16839
# 3       83596_0_4       83596    83596_0          pe_ann       19257
# 4       83596_0_5       83596    83596_0          pe_ann       19866
# 5       68870_1_1       68870    68870_1          pe_ann        1501
# 6       68870_1_2       68870    68870_1          pe_ann       12322
# 7       68870_1_3       68870    68870_1          pe_ann       12583
# 8       68870_1_4       68870    68870_1          pe_ann        8922
# 9        9545_2_1        9545     9545_2          pe_ann        2994
# 10       9545_2_2        9545     9545_2          pe_ann        9860
# 11      21830_3_1       21830    21830_3          pe_ann        1136
# 12      21830_3_2       21830    21830_3          pe_ann        2611
# 13      21830_3_3       21830    21830_3          pe_ann        3086
# 14      21830_3_4       21830    21830_3          pe_ann        8379
# 15      51660_4_1       51660    51660_4          pe_ann        2061
# 16      51660_4_2       51660    51660_4          pe_ann        7728
# 17      68251_5_1       68251    68251_5          pe_ann        8773
# 18      68251_5_2       68251    68251_5          pe_ann       10142
# 19      68251_5_3       68251    68251_5          pe_ann        2199
# 20      68251_5_4       68251    68251_5          pe_ann        5865
# 21      68251_5_5       68251    68251_5          pe_ann        7895
# 22      68251_5_6       68251    68251_5          pe_ann        9336
# 23      81846_6_1       81846    81846_6          pe_ann        1959
# 24      81846_6_2       81846    81846_6          pe_ann       13582
# 25      81846_6_3       81846    81846_6          pe_ann       15718
# 26      81846_6_4       81846    81846_6          pe_ann       15751
# 27      81846_6_5       81846    81846_6          pe_ann        3346
# 28      81846_6_6       81846    81846_6          pe_ann        8251
# 29      85050_7_1       85050    85050_7          pe_ann        1376
# ...           ...         ...        ...             ...         ...
# 1869  92995_329_4       92995  92995_329          pe_ann         697
# 1870  92995_329_5       92995  92995_329          pe_ann        1796
# 1871  43943_330_1       43943  43943_330          pe_ann         146
# 1872  43943_330_2       43943  43943_330          pe_ann         371
# 1873  43943_330_3       43943  43943_330          pe_ann         961
# 1874  43943_330_4       43943  43943_330          pe_ann        2850
# 1875  43943_330_5       43943  43943_330          pe_ann         542
# 1876  43943_330_6       43943  43943_330          pe_ann        3238
# 1877  94329_331_1       94329  94329_331          pe_ann         158
# 1878  94329_331_2       94329  94329_331          pe_ann         446
# 1879  94329_331_3       94329  94329_331          pe_ann         648
# 1880  94329_331_4       94329  94329_331          pe_ann        1202
# 1881  94329_331_5       94329  94329_331          pe_ann        2110
# 1882  94329_331_6       94329  94329_331          pe_ann        3057
# 1883  94329_331_7       94329  94329_331          pe_ann        3815
# 1884  40133_332_1       40133  40133_332          pe_ann         150
# 1885  40133_332_2       40133  40133_332          pe_ann         385
# 1886  40133_332_3       40133  40133_332          pe_ann         621
# 1887  40133_332_4       40133  40133_332          pe_ann         865
# 1888  40133_332_5       40133  40133_332          pe_ann        1950
# 1889  63932_333_1       63932  63932_333          pe_ann         151
# 1890  63932_333_2       63932  63932_333          pe_ann         417
# 1891  63932_333_3       63932  63932_333          pe_ann        2708
# 1892  63932_333_4       63932  63932_333          pe_ann         640
# 1893  63932_333_5       63932  63932_333          pe_ann        1287
# 1894  63932_333_6       63932  63932_333          pe_ann        2399
# 1895  81384_334_1       81384  81384_334          pe_ann         397
# 1896  81384_334_2       81384  81384_334          pe_ann         642
# 1897  81384_334_3       81384  81384_334          pe_ann        1378
# 1898  81384_334_4       81384  81384_334          pe_ann        2672
#
#       span_end          PAD_snippet  neg_flag
# 0         1984                   PE         0
# 1        16912                   PE         0
# 2        16857   Pulmonary Embolism         0
# 3        19275   Pulmonary embolism         0
# 4        19884   Pulmonary Embolism         0
# 5         1503                   PE         0
# 6        12324                   PE         0
# 7        12585                   PE         1
# 8         8940   pulmonary embolism         0
# 9         2996                   PE         1
# 10        9878   pulmonary embolism         1
# 11        1154   pulmonary embolism         0
# 12        2627     pulmonary emboli         0
# 13        3104   pulmonary embolism         0
# 14        8397   pulmonary embolism         0
# 15        2063                   PE         0
# 16        7746   Pulmonary embolism         0
# 17        8775                   PE         0
# 18       10144                   PE         0
# 19        2217  pulmonary\nembolism         0
# 20        5882    pulmonary embolus         0
# 21        7913   PULMONARY EMBOLISM         0
# 22        9353   pulmonary\nembolus         0
# 23        1961                   PE         1
# 24       13584                   PE         0
# 25       15720                   PE         0
# 26       15753                   PE         1
# 27        3364   pulmonary embolism         0
# 28        8269   pulmonary embolism         1
# 29        1378                   PE         0
# ...        ...                  ...       ...
# 1869       715   pulmonary embolism         0
# 1870      1814   pulmonary embolism         1
# 1871       148                   PE         0
# 1872       373                   PE         0
# 1873       963                   PE         0
# 1874      2852                   PE         0
# 1875       560   pulmonary embolism         0
# 1876      3256   pulmonary embolism         1
# 1877       176   pulmonary embolism         0
# 1878       464   pulmonary embolism         0
# 1879       666   pulmonary embolism         1
# 1880      1220   pulmonary embolism         0
# 1881      2128   pulmonary embolism         0
# 1882      3075   pulmonary embolism         0
# 1883      3833   pulmonary embolism         1
# 1884       152                   PE         0
# 1885       387                   PE         0
# 1886       639   pulmonary embolism         0
# 1887       883   pulmonary embolism         0
# 1888      1968   pulmonary embolism         0
# 1889       153                   PE         0
# 1890       419                   PE         0
# 1891      2710                   PE         0
# 1892       658   pulmonary embolism         1
# 1893      1305   pulmonary embolism         0
# 1894      2417   pulmonary embolism         1
# 1895       415   pulmonary embolism         0
# 1896       660   pulmonary embolism         0
# 1897      1396   pulmonary embolism         0
# 1898      2690   pulmonary embolism         0
#
# [1899 rows x 8 columns]

# %%
result_data_frame.to_csv('out_table.csv', index=False)
print('Done')
# Out:
# Done

# %% [markdown]
# ## This completes the development and deployment of the Classification system
